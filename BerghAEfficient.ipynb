# %%
include("StackyFan.jl")
# Out:
# showStackyFan

# %%
X=Polymake.fulton.NormalToricVariety(INPUT_RAYS=[1 0 0;1 1 0;1 0 1;1 1 1],INPUT_CONES=[[0,1,2,3]])
makeSmooth(X).INPUT_RAYS
# Out:
# UndefVarError: makeSmooth not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[4]:2
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

# %%
X=Polymake.fulton.NormalToricVariety(INPUT_RAYS=[1 0; 1 2],INPUT_CONES=[[0,1]]);

toric_blowup([0,1],X,[1,1]).INPUT_CONES
# Out:
# pm::IncidenceMatrix<pm::NonSymmetric>
# {0 2}
# {1 2}

# %%
X=Polymake.fulton.NormalToricVariety(INPUT_RAYS=[4 1; 7 8],INPUT_CONES=[[0,1]]);
F=addStackStructure(X,[1,1]);
Y=BerghA(F,[1,1],verbose=true)
showStackyFan(Y)
# Out:
# ==algorithm is running in verbose mode==
#
# =======
# Number of extremal cones: 1
# Maximal non-distinguished rays and multiplicity: 0, 25
# =======
# Number of extremal cones: 1
# Maximal non-distinguished rays and multiplicity: 0, 10
# =======
# Number of extremal cones: 1
# Maximal non-distinguished rays and multiplicity: 0, 5
# =======
# Number of extremal cones: 1
# Maximal non-distinguished rays and multiplicity: 0, 2
# =======
# Number of steps: 4

# %%
showStackyFan(Y,stackypoints=false)

# %%
X=Polymake.fulton.NormalToricVariety(INPUT_RAYS=[1 0; 4 3; 1 5],INPUT_CONES=[[0,1],[1,2]]);
F=addStackStructure(X,[1,1,1]);
Y=BerghA(F,[1,1,1])
showStackyFan(Y,stackypoints=false)

# %%
X=Polymake.fulton.NormalToricVariety(INPUT_RAYS=[1 0 2; 2 1 1; 5 3 9],INPUT_CONES=[[0,1,2]]);
F=addStackStructure(X,[1,1,1]);
showStackyFan(BerghA(F,[1,1,1]))
